# %%
# Import functions from preprocessing.py
import sys
import os

# Add the path to the src directory
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# Import functions from src
from utils import prepare_data
from evaluate import evaluate

# %%
# Load the dataset and prepare the data
text_train, text_test, y_train, y_test = prepare_data("AirlineTweets.csv")

# Fit and plot the model
evaluate(model_name = 'LogisticRegression',
         n_feature = [100, 500, 1000, 1500, 2000],
         text_train=text_train, text_test=text_test, y_train=y_train, y_test=y_test,
         save=True)
# Out:
# ...
# 100%|██████████| 5/5 [00:47<00:00,  9.44s/it]
